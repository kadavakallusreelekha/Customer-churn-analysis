# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"/content/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.describe(include=object)
# Out:
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7043    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     3186-AJIEK   Male      No         No          Yes            No
# freq             1   3555    3641       4933         6361          3390
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7043           7043         7043             7043
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         7043        7043            7043            7043
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
(df==" ").sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df['TotalCharges']=pd.to_numeric(df["TotalCharges"],errors='coerce')

# %%
df.loc[df['tenure']==0,'TotalCharge']=0

# %%
df['Churn_numeric']=df['Churn'].map({'Yes':1,'No':0})

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... StreamingTV  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...          No
# 4                No     Fiber optic             No  ...          No
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# ...

# %%
df['TotalCharges'].isna().sum()
# Out:
# np.int64(11)

# %%
df[df['TotalCharges'].isna()][['tenure', 'MonthlyCharges', 'TotalCharges']]
# Out:
#       tenure  MonthlyCharges  TotalCharges
# 488        0           52.55           NaN
# 753        0           20.25           NaN
# 936        0           80.85           NaN
# 1082       0           25.75           NaN
# 1340       0           56.05           NaN
# 3331       0           19.85           NaN
# 3826       0           25.35           NaN
# 4380       0           20.00           NaN
# 5218       0           19.70           NaN
# 6670       0           73.35           NaN
# 6754       0           61.90           NaN

# %%
df['TotalCharges'] = df['MonthlyCharges'] * df['tenure']

# %%
df.loc[df['TotalCharges'].isna(), 'TotalCharges'] = (
    df.loc[df['TotalCharges'].isna(), 'MonthlyCharges'] *
    df.loc[df['TotalCharges'].isna(), 'tenure']
)

# %%
df['TotalCharges'].isna().sum()
# Out:
# np.int64(0)

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
sns.countplot(df["Churn"],color="skyblue")
# Out:
# <Axes: xlabel='count', ylabel='Churn'>

# %%
sns.histplot(df["tenure"],kde=True)
# Out:
# <Axes: xlabel='tenure', ylabel='Count'>

# %%
numeric_col=df.select_dtypes(include=np.number).columns
corr=df[numeric_col].corr()

plt.figure(figsize=(10,8))
sns.heatmap(corr,annot=True,cmap='viridis',center=0)
# Out:
# <Axes: >

# %%
sns.boxplot(x=df['MonthlyCharges'])
# Out:
# <Axes: xlabel='MonthlyCharges'>

# %%
sns.boxplot(x='Churn', y='MonthlyCharges', data=df)
# Out:
# <Axes: xlabel='Churn', ylabel='MonthlyCharges'>

# %%
cols_to_encode = ['gender', 'Contract', 'InternetService']

df_encoded = pd.get_dummies(
    df,
    columns=cols_to_encode,
    drop_first=True
)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... StreamingTV  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...          No
# 4                No     Fiber optic             No  ...          No
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# ...

# %%
df_encoded.head()
df_encoded.dtypes
# Out:
# customerID                      object
# SeniorCitizen                    int64
# Partner                         object
# Dependents                      object
# tenure                           int64
# PhoneService                    object
# MultipleLines                   object
# OnlineSecurity                  object
# OnlineBackup                    object
# DeviceProtection                object
# TechSupport                     object
# StreamingTV                     object
# StreamingMovies                 object
# PaperlessBilling                object
# PaymentMethod                   object
# MonthlyCharges                 float64
# TotalCharges                   float64
# Churn                           object
# TotalCharge                    float64
# Churn_numeric                    int64
# gender_Male                       bool
# Contract_One year                 bool
# Contract_Two year                 bool
# InternetService_Fiber optic       bool
# ...

# %%
X = df_encoded.drop('Churn', axis=1)
y = df_encoded['Churn']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,      # 20% test data
    random_state=42     # reproducibility
)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (5634, 24)
# (1409, 24)
# (5634,)
# (1409,)

# %%
numeric_col = df.select_dtypes(include='number').columns
numeric_col
# Out:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges',
#        'TotalCharge', 'Churn_numeric'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scaled = df.copy()

df_scaled[numeric_col] = scaler.fit_transform(df[numeric_col])

# %%
df_scaled.head()
df_scaled[numeric_col].describe()
# Out:
#        SeniorCitizen        tenure  MonthlyCharges  TotalCharges  TotalCharge  \
# count   7.043000e+03  7.043000e+03    7.043000e+03  7.043000e+03         11.0
# mean   -4.842546e-17 -2.421273e-17   -6.406285e-17  3.026591e-17          0.0
# std     1.000071e+00  1.000071e+00    1.000071e+00  1.000071e+00          0.0
# min    -4.399165e-01 -1.318165e+00   -1.545860e+00 -1.006629e+00          0.0
# 25%    -4.399165e-01 -9.516817e-01   -9.725399e-01 -8.326448e-01          0.0
# 50%    -4.399165e-01 -1.372744e-01    1.857327e-01 -3.912362e-01          0.0
# 75%    -4.399165e-01  9.214551e-01    8.338335e-01  6.652563e-01          0.0
# max     2.273159e+00  1.613701e+00    1.794352e+00  2.768924e+00          0.0
#
#        Churn_numeric
# count   7.043000e+03
# mean   -7.667364e-17
# std     1.000071e+00
# min    -6.010235e-01
# 25%    -6.010235e-01
# 50%    -6.010235e-01
# 75%     1.663829e+00
# max     1.663829e+00

# %%
numeric_col = df.select_dtypes(include='number').columns

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
sns.histplot(df['MonthlyCharges'], kde=True)
plt.title("Before Scaling – MonthlyCharges")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scaled = df.copy()

df_scaled[numeric_col] = scaler.fit_transform(df[numeric_col])

# %%
plt.figure(figsize=(6,4))
sns.histplot(df_scaled['MonthlyCharges'], kde=True)
plt.title("After Scaling – MonthlyCharges")
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,4))

sns.histplot(df['MonthlyCharges'], kde=True, ax=axes[0])
axes[0].set_title("Before Scaling")

sns.histplot(df_scaled['MonthlyCharges'], kde=True, ax=axes[1])
axes[1].set_title("After Scaling")

plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,4))

sns.boxplot(x=df['MonthlyCharges'], ax=axes[0])
axes[0].set_title("Before Scaling")

sns.boxplot(x=df_scaled['MonthlyCharges'], ax=axes[1])
axes[1].set_title("After Scaling")

plt.show()

# %%
df[numeric_col].hist(figsize=(10,8))
plt.suptitle("Before Scaling")
plt.show()

df_scaled[numeric_col].hist(figsize=(10,8))
plt.suptitle("After Scaling")
plt.show()
